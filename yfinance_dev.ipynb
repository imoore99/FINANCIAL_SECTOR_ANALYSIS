# %% [markdown]
# Import Packages

# %%
import pandas as pd
import yfinance as yf
import logging 

pd.set_option('display.float_format', '{:.2f}'.format)

# Configure the 'yfinance' logger to suppress output
logger = logging.getLogger('yfinance')
logger.disabled = True
# Optional: prevent propagation to the root logger as well
logger.propagate = False

# %%
## OUTLINE:
## 1. Value vs. Growth - x=P/E Ratio, y=TTM, r=MarketCap
## 2. Risk-Return - x=beta, y=1yr total return, r=MarketCap
## 3. Profitability vs. Efficiency - x=ROE, y=Net Margin, r=MarketCap
## 4. Quality vs. Valuation - x=P/B Ratio, y=ROA, r=MarketCap
## 5. Leverage vs coverage - x=Debt/EBITDA, y=interest coverage ratio, r=MarketCap
## 6. Momentum vs.Value - 6-Month Price Return (%)

# %% [markdown]
# yfinance API - s&p 500

# %%
def process_tickers(url):
    df = pd.read_csv(url)
    tickers = df['Symbol'].tolist()
    return tickers

# %%
def top_20_market_cap(tickers):
    # Batch download 1-day price data for all tickers - MUCH more efficient
    print("Downloading price data for all tickers...")
    price_data = yf.download(tickers, period='1d', progress=False, group_by='ticker')
    
    market_cap_list = []
    ticker_list = []
    
    for i in tickers:
        try:
            # Get the latest close price from the batch download
            if len(tickers) == 1:
                close_price = price_data['Close'].iloc[-1]
            else:
                close_price = price_data[i]['Close'].iloc[-1]
            
            # Only make individual API call to get shares outstanding
            ticker = yf.Ticker(i)
            shares = ticker.info.get('sharesOutstanding')
            
            if shares and close_price:
                market_cap = close_price * shares
                market_cap_list.append(market_cap)
                ticker_list.append(i)
        except:
            pass
        
    df = pd.DataFrame(data={'ticker': ticker_list, 'marketCap':market_cap_list}).sort_values(by='marketCap', ascending=False).reset_index(drop=True)

    top_20_market_cap = df[df['ticker'] != 'GOOG'][:20].reset_index(drop=True)

    return top_20_market_cap

# %%
def json_data(df):
    # Batch download 1-year price history for top 20 tickers only
    print("Downloading 1-year history for top 20 tickers...")
    top_tickers = df['ticker'].tolist()
    history_data = yf.download(top_tickers, period='1y', progress=False, group_by='ticker')
    
    json_output = []

    for index, row in df.iterrows():
        ticker = yf.Ticker(row.ticker)

        # Get history from the batch download instead of individual API call
        if len(top_tickers) == 1:
            history = history_data
        else:
            history = history_data[row.ticker]

        history = ticker.history(period='1y')

        # Calculate returns - 1 year and 6 months
        # Use more lenient thresholds - yfinance doesn't always return exactly 252 days
        if len(history) >= 200:  # At least ~8 months of data for "1 year" return
            one_year_return = float(((history['Close'].iloc[-1] / history['Close'].iloc[0]) - 1) * 100)
        else:
            one_year_return = None
                
        if len(history) >= 100:  # At least ~4 months of data for "6 month" return
            # Use the midpoint or as far back as we can go
            lookback_index = min(126, len(history) - 1)
            six_month_return = float(((history['Close'].iloc[-1] / history['Close'].iloc[-lookback_index]) - 1) * 100)
        else:
            six_month_return = None

        # Calculate Interest Coverage Ratio
        income_statement = ticker.income_stmt
        if 'EBIT' in income_statement.index and 'Interest Expense' in income_statement.index:
            ebit = income_statement.loc['EBIT'].iloc[0]
            interest_expense = abs(income_statement.loc['Interest Expense'].iloc[0])  # Usually negative
            
            if interest_expense > 0:
                    interest_coverage = float(ebit / interest_expense)
            else:
                interest_coverage = None
        else:
                interest_coverage = None

        structure =  {
            #core information
            'ticker': row.ticker,
            'sector': ticker.info.get('sector'),
            'company_name': ticker.info.get('longName', ticker),
            'industry': ticker.info.get('industry'),

            #market cap
            'market_cap': row.marketCap,

            # Valuation
            'pe_ratio': ticker.info.get('trailingPE'),
            'forward_pe_ratio':ticker.info.get('forwardPE'),
            'pb_ratio':ticker.info.get('priceToBook'),
            'ps_ratio': ticker.info.get('priceToSalesTrailing12Months'),
            'ev_to_revenue': ticker.info.get('enterpriseToRevenue'),
            'ev_to_ebitda': ticker.info.get('enterpriseToEbitda'),

            #Growth
            'rev_growth': ticker.info.get('revenueGrowth', 0) * 100 if ticker.info.get('revenueGrowth') else None,  # Convert to %
            'earnings_growth': ticker.info.get('earningsGrowth', 0) * 100 if ticker.info.get('earningsGrowth') else None,

            # Profitability
            'roe': ticker.info.get('returnOnEquity', 0) * 100 if ticker.info.get('returnOnEquity') else None,
            'roa': ticker.info.get('returnOnAssets', 0) * 100 if ticker.info.get('returnOnAssets') else None,
            'operating_margin': ticker.info.get('operatingMargins', 0) * 100 if ticker.info.get('operatingMargins') else None,
            'net_margin': ticker. info.get('profitMargins', 0) * 100 if ticker.info.get('profitMargins') else None,
            'profit_margin': ticker.info.get('profitMargins', 0) * 100 if ticker.info.get('profitMargins') else None,
                    
            # Risk
            'beta':ticker.info.get('beta'),
                    
            # Returns (calculated)
            'one_year_return': one_year_return,
            'six_month_return': six_month_return,
                    
            # Leverage
            'debt_to_equity': ticker.info.get('debtToEquity'),
            'total_debt': ticker.info.get('totalDebt'),
            'total_cash': ticker.info.get('totalCash'),

            # Coverage
            'interest_coverage': interest_coverage,
                    
            # Other
            'avg_vol': ticker.info.get('averageVolume')
        }
        json_output.append(structure)

    return json_output

# %%
def json_constructor(url):
    #scrape s&P 500 ticker list
    tickers = process_tickers(url)
    #baseline df for additional columns
    top_20_market_cap_df = top_20_market_cap(tickers)
    #construct json format
    json_data_output = json_data(top_20_market_cap_df)

    return json_data_output

# %%
# DataSets repo - updated regularly
url = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/main/data/constituents.csv"

# %%
tickers = process_tickers(url)

# %%
top_20_market_cap_df = top_20_market_cap(tickers)
# Out:
# Downloading price data for all tickers...

# %%
json_data_output = json_data(top_20_market_cap_df)
# Out:
# Downloading 1-year history for top 20 tickers...
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 json_data_output = json_data(top_20_market_cap_df)
#
# Cell In[27], line 50, in json_data(df)
#      44     else:
#      45             interest_coverage = None
#      47     structure =  {
#      48         #core information
#      49         'ticker': row.ticker,
# ---> 50         'sector': ticker.info.get('sector'),
#      51         'company_name': ticker.info.get('longName', ticker),
#      52         'industry': ticker.info.get('industry'),
#      53
#      54         #market cap
#      55         'market_cap': row.marketCap,
#      56
#      57         # Valuation
#      58         'pe_ratio': ticker.info.get('trailingPE'),
#      59         'forward_pe_ratio':ticker.info.get('forwardPE'),
#      60         'pb_ratio':ticker.info.get('priceToBook'),
#      61         'ps_ratio': ticker.info.get('priceToSalesTrailing12Months'),
#      62         'ev_to_revenue': ticker.info.get('enterpriseToRevenue'),
#      63         'ev_to_ebitda': ticker.info.get('enterpriseToEbitda'),
#      64
#      65         #Growth
#      66         'rev_growth': ticker.info.get('revenueGrowth', 0) * 100 if ticker.info.get('revenueGrowth') else None,  # Convert to %
#      67         'earnings_growth': ticker.info.get('earningsGrowth', 0) * 100 if ticker.info.get('earningsGrowth') else None,
#      68
#      69         # Profitability
#      70         'roe': ticker.info.get('returnOnEquity', 0) * 100 if ticker.info.get('returnOnEquity') else None,
#      71         'roa': ticker.info.get('returnOnAssets', 0) * 100 if ticker.info.get('returnOnAssets') else None,
#      72         'operating_margin': ticker.info.get('operatingMargins', 0) * 100 if ticker.info.get('operatingMargins') else None,
#      73         'net_margin': ticker. info.get('profitMargins', 0) * 100 if ticker.info.get('profitMargins') else None,
#      74         'profit_margin': ticker.info.get('profitMargins', 0) * 100 if ticker.info.get('profitMargins') else None,
#      75
#      76         # Risk
#      77         'beta':ticker.info.get('beta'),
#      78
#      79         # Returns (calculated)
#      80         'one_year_return': one_year_return,
#      81         'six_month_return': six_month_return,
#      82
#      83         # Leverage
#      84         'debt_to_equity': ticker.info.get('debtToEquity'),
#      85         'total_debt': ticker.info.get('totalDebt'),
#      86         'total_cash': ticker.info.get('totalCash'),
#      87
#      88         # Coverage
#      89         'interest_coverage': interest_coverage,
#      90
#      91         # Other
#      92         'avg_vol': ticker.info.get('averageVolume')
#      93     }
#      94     json_output.append(structure)
#      96 return json_output
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/ticker.py:159, in Ticker.info(self)
#     157 @property
#     158 def info(self) -> dict:
# --> 159     return self.get_info()
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/base.py:282, in TickerBase.get_info(self)
#     281 def get_info(self) -> dict:
# --> 282     data = self._quote.info
#     283     return data
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/scrapers/quote.py:503, in Quote.info(self)
#     500 @property
#     501 def info(self) -> dict:
#     502     if self._info is None:
# --> 503         self._fetch_info()
#     504         self._fetch_complementary()
#     506     return self._info
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/scrapers/quote.py:612, in Quote._fetch_info(self)
#     610 self._already_fetched = True
#     611 modules = ['financialData', 'quoteType', 'defaultKeyStatistics', 'assetProfile', 'summaryDetail']
# --> 612 result = self._fetch(modules=modules)
#     613 additional_info = self._fetch_additional_info()
#     614 if additional_info is not None and result is not None:
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/scrapers/quote.py:588, in Quote._fetch(self, modules)
#     586 params_dict = {"modules": modules, "corsDomain": "finance.yahoo.com", "formatted": "false", "symbol": self._symbol}
#     587 try:
# --> 588     result = self._data.get_raw_json(_QUOTE_SUMMARY_URL_ + f"/{self._symbol}", params=params_dict)
#     589 except curl_cffi.requests.exceptions.HTTPError as e:
#     590     if not YfConfig.debug.hide_exceptions:
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:462, in YfData.get_raw_json(self, url, params, timeout)
#     460 def get_raw_json(self, url, params=None, timeout=30):
#     461     utils.get_yf_logger().debug(f'get_raw_json(): {url}')
# --> 462     response = self.get(url, params=params, timeout=timeout)
#     463     response.raise_for_status()
#     464     return response.json()
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:375, in YfData.get(self, url, params, timeout)
#     373 @utils.log_indent_decorator
#     374 def get(self, url, params=None, timeout=30):
# --> 375     response = self._make_request(url, request_method = self._session.get, params=params, timeout=timeout)
#     377     # Accept cookie-consent if redirected to consent page
#     378     if not self._is_this_consent_url(response.url):
#     379         # "Consent Page not detected"
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:444, in YfData._make_request(self, url, request_method, body, params, timeout, data)
#     442 else:
#     443     self._set_cookie_strategy('basic')
# --> 444 crumb, strategy = self._get_cookie_and_crumb(timeout)
#     445 request_args['params']['crumb'] = crumb
#     446 response = request_method(**request_args)
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:365, in YfData._get_cookie_and_crumb(self, timeout)
#     362         crumb = self._get_cookie_and_crumb_basic(timeout)
#     363 else:
#     364     # Fallback strategy
# --> 365     crumb = self._get_cookie_and_crumb_basic(timeout)
#     366     if crumb is None:
#     367         # Fail
#     368         self._set_cookie_strategy('csrf', have_lock=True)
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:246, in YfData._get_cookie_and_crumb_basic(self, timeout)
#     244 if not self._get_cookie_basic(timeout):
#     245     return None
# --> 246 return self._get_crumb_basic(timeout)
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:233, in YfData._get_crumb_basic(self, timeout)
#     231 if crumb_response.status_code == 429 or "Too Many Requests" in self._crumb:
#     232     utils.get_yf_logger().debug(f"Didn't receive crumb {self._crumb}")
# --> 233     raise YFRateLimitError()
#     235 if self._crumb is None or '<html>' in self._crumb:
#     236     utils.get_yf_logger().debug("Didn't receive crumb")
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.

# %%
json_data_output
# Out:
# [{'ticker': 'NVDA',
#   'sector': 'Technology',
#   'company_name': 'NVIDIA Corporation',
#   'industry': 'Semiconductors',
#   'market_cap': 4554106601472.0,
#   'pe_ratio': 46.185184,
#   'forward_pe_ratio': 24.61926,
#   'pb_ratio': 38.235893,
#   'ps_ratio': 24.335033,
#   'ev_to_revenue': 23.514,
#   'ev_to_ebitda': 39.048,
#   'rev_growth': 62.5,
#   'earnings_growth': 66.7,
#   'roe': 107.35900000000001,
#   'roa': 53.528,
#   'operating_margin': 63.168997000000005,
#   'net_margin': 53.007000000000005,
#   'profit_margin': 53.007000000000005,
#   'beta': 2.314,
#   'one_year_return': np.float64(40.0772346807599),
#   'six_month_return': np.float64(8.503543523002177),
#   'debt_to_equity': 9.102,
#   'total_debt': 10821999616,
#   'total_cash': 60608000000,
#   'interest_coverage': np.float64(341.1862348178138),
#   'avg_vol': 182945991},
#  {'ticker': 'GOOGL',
#   'sector': 'Communication Services',
#   'company_name': 'Alphabet Inc.',
#   'industry': 'Internet Content & Information',
#   'market_cap': 4030671880192.0,
#   'pe_ratio': 32.81854,
#   'forward_pe_ratio': 29.545017,
#   'pb_ratio': 10.388661,
#   'ps_ratio': 10.456349,
#   'ev_to_revenue': 10.372,
#   'ev_to_ebitda': 27.541,
#   'rev_growth': 15.9,
#   'earnings_growth': 35.3,
#   'roe': 35.449999999999996,
#   'roa': 16.275999,
#   'operating_margin': 30.512,
#   'net_margin': 32.233003,
#   'profit_margin': 32.233003,
#   'beta': 1.086,
#   'one_year_return': np.float64(73.18090751935762),
#   'six_month_return': np.float64(80.10131688497484),
#   'debt_to_equity': 11.424,
#   'total_debt': 44195000320,
#   'total_cash': 98496004096,
#   'interest_coverage': np.float64(448.07089552238807),
#   'avg_vol': 36284843},
#  {'ticker': 'AAPL',
#   'sector': 'Technology',
#   'company_name': 'Apple Inc.',
#   'industry': 'Consumer Electronics',
#   'market_cap': 3815401848832.0,
#   'pe_ratio': 34.6126,
#   'forward_pe_ratio': 28.215755,
#   'pb_ratio': 51.73512,
#   'ps_ratio': 9.168091,
#   'ev_to_revenue': 9.369,
#   'ev_to_ebitda': 26.936,
#   'rev_growth': 7.9,
#   'earnings_growth': 91.2,
#   'roe': 171.42199,
#   'roa': 22.964000000000002,
#   'operating_margin': 31.647,
#   'net_margin': 26.915001999999998,
#   'profit_margin': 26.915001999999998,
#   'beta': 1.093,
#   'one_year_return': np.float64(13.632616936931118),
#   'six_month_return': np.float64(22.527526434899038),
#   'debt_to_equity': 152.411,
#   'total_debt': 112377004032,
#   'total_cash': 54697000960,
#   'interest_coverage': None,
#   'avg_vol': 45860329},
#  {'ticker': 'MSFT',
#   'sector': 'Technology',
#   'company_name': 'Microsoft Corporation',
#   'industry': 'Software - Infrastructure',
#   'market_cap': 3394429779968.0,
#   'pe_ratio': 32.479374,
#   'forward_pe_ratio': 24.358265,
#   'pb_ratio': 9.350122,
#   'ps_ratio': 11.553067,
#   'ev_to_revenue': 11.683,
#   'ev_to_ebitda': 20.624,
#   'rev_growth': 18.4,
#   'earnings_growth': 12.7,
#   'roe': 32.241002,
#   'roa': 14.655999999999999,
#   'operating_margin': 48.873,
#   'net_margin': 35.707,
#   'profit_margin': 35.707,
#   'beta': 1.073,
#   'one_year_return': np.float64(8.349121749870637),
#   'six_month_return': np.float64(-10.152565795778202),
#   'debt_to_equity': 33.154,
#   'total_debt': 120375001088,
#   'total_cash': 102012002304,
#   'interest_coverage': np.float64(52.835220125786165),
#   'avg_vol': 23650140},
#  {'ticker': 'AMZN',
#   'sector': 'Consumer Cyclical',
#   'company_name': 'Amazon.com, Inc.',
#   'industry': 'Internet Retail',
#   'market_cap': 2546195496960.0,
#   'pe_ratio': 33.641243,
#   'forward_pe_ratio': 30.298674,
#   'pb_ratio': 6.8864017,
#   'ps_ratio': 3.6830392,
#   'ev_to_revenue': 3.755,
#   'ev_to_ebitda': 18.584,
#   'rev_growth': 13.4,
#   'earnings_growth': 36.4,
#   'roe': 24.326999999999998,
#   'roa': 7.495,
#   'operating_margin': 11.057,
#   'net_margin': 11.063,
#   'profit_margin': 11.063,
#   'beta': 1.376,
#   'one_year_return': np.float64(7.939811802278296),
#   'six_month_return': np.float64(5.328787658768874),
#   'debt_to_equity': 43.405,
#   'total_debt': 160437993472,
#   'total_cash': 94196998144,
#   'interest_coverage': np.float64(29.517871986699916),
#   'avg_vol': 44764091},
#  {'ticker': 'AVGO',
#   'sector': 'Technology',
#   'company_name': 'Broadcom Inc.',
#   'industry': 'Semiconductors',
#   'market_cap': 1626351599616.0,
#   'pe_ratio': 72.06302,
#   'forward_pe_ratio': 24.388508,
#   'pb_ratio': 5.792202,
#   'ps_ratio': 25.456692,
#   'ev_to_revenue': 2.646,
#   'ev_to_ebitda': 4.83,
#   'rev_growth': 16.400000000000002,
#   'earnings_growth': 188.1,
#   'roe': 31.048,
#   'roa': 9.788,
#   'operating_margin': 31.765,
#   'net_margin': 36.198002,
#   'profit_margin': 36.198002,
#   'beta': 1.218,
#   'one_year_return': np.float64(50.873827145446995),
#   'six_month_return': np.float64(21.502493161749392),
#   'debt_to_equity': 166.032,
#   'total_debt': 40456998912,
#   'total_cash': 11105000448,
#   'interest_coverage': np.float64(8.080685358255451),
#   'avg_vol': 28441687},
#  {'ticker': 'META',
#   'sector': 'Communication Services',
#   'company_name': 'Meta Platforms, Inc.',
#   'industry': 'Internet Content & Information',
#   'market_cap': 1564743565312.0,
#   'pe_ratio': 27.481186,
#   'forward_pe_ratio': 20.435034,
#   'pb_ratio': 8.064432,
#   'ps_ratio': 8.259052,
#   'ev_to_revenue': 8.224,
#   'ev_to_ebitda': 15.834,
#   'rev_growth': 26.200000000000003,
#   'earnings_growth': -82.6,
#   'roe': 32.643001999999996,
#   'roa': 18.013,
#   'operating_margin': 40.075,
#   'net_margin': 30.891999999999996,
#   'profit_margin': 30.891999999999996,
#   'beta': 1.287,
#   'one_year_return': np.float64(1.8742983813392122),
#   'six_month_return': np.float64(-11.721810517574427),
#   'debt_to_equity': 26.311,
#   'total_debt': 51059998720,
#   'total_cash': 44447997952,
#   'interest_coverage': np.float64(99.82937062937063),
#   'avg_vol': 18299103},
#  {'ticker': 'TSLA',
#   'sector': 'Consumer Cyclical',
#   'company_name': 'Tesla, Inc.',
#   'industry': 'Auto Manufacturers',
#   'market_cap': 1458604474368.0,
#   'pe_ratio': 302.46207,
#   'forward_pe_ratio': 201.77591,
#   'pb_ratio': 18.229694,
#   'ps_ratio': 15.252105,
#   'ev_to_revenue': 14.991,
#   'ev_to_ebitda': 133.134,
#   'rev_growth': 11.600000000000001,
#   'earnings_growth': -37.1,
#   'roe': 6.7909999999999995,
#   'roa': 2.35,
#   'operating_margin': 6.628,
#   'net_margin': 5.314,
#   'profit_margin': 5.314,
#   'beta': 1.835,
#   'one_year_return': np.float64(5.980861138163607),
#   'six_month_return': np.float64(33.0411088865171),
#   'debt_to_equity': 17.082,
#   'total_debt': 13788000256,
#   'total_cash': 41647001600,
#   'interest_coverage': np.float64(26.685714285714287),
#   'avg_vol': 78441332},
#  {'ticker': 'WMT',
#   'sector': 'Consumer Defensive',
#   'company_name': 'Walmart Inc.',
#   'industry': 'Discount Stores',
#   'market_cap': 950363815936.0,
#   'pe_ratio': 41.67832,
#   'forward_pe_ratio': 40.129005,
#   'pb_ratio': 9.888833,
#   'ps_ratio': 1.3517517,
#   'ev_to_revenue': 1.452,
#   'ev_to_ebitda': 23.904,
#   'rev_growth': 5.800000000000001,
#   'earnings_growth': 35.199999999999996,
#   'roe': 23.660999999999998,
#   'roa': 6.539000000000001,
#   'operating_margin': 3.73,
#   'net_margin': 3.259,
#   'profit_margin': 3.259,
#   'beta': 0.661,
#   'one_year_return': np.float64(31.808309708630734),
#   'six_month_return': np.float64(25.9568082402571),
#   'debt_to_equity': 66.747,
#   'total_debt': 68423999488,
#   'total_cash': 10581999616,
#   'interest_coverage': np.float64(10.644061583577713),
#   'avg_vol': 19876440},
#  {'ticker': 'LLY',
#   'sector': 'Healthcare',
#   'company_name': 'Eli Lilly and Company',
#   'industry': 'Drug Manufacturers - General',
#   'market_cap': 926012932096.0,
#   'pe_ratio': 50.660618,
#   'forward_pe_ratio': 31.532808,
#   'pb_ratio': 38.89194,
#   'ps_ratio': 15.584249,
#   'ev_to_revenue': 16.724,
#   'ev_to_ebitda': 34.59,
#   'rev_growth': 53.900000000000006,
#   'earnings_growth': 480.40000000000003,
#   'roe': 96.47,
#   'roa': 17.603001,
#   'operating_margin': 48.294,
#   'net_margin': 30.986000000000004,
#   'profit_margin': 30.986000000000004,
#   'beta': 0.347,
#   'one_year_return': np.float64(37.364666927097254),
#   'six_month_return': np.float64(34.34569405355958),
#   'debt_to_equity': 178.516,
#   'total_debt': 42577600512,
#   'total_cash': 9913499648,
#   'interest_coverage': np.float64(17.244427363566487),
#   'avg_vol': 3495372},
#  {'ticker': 'JPM',
#   'sector': 'Financial Services',
#   'company_name': 'JPMorgan Chase & Co.',
#   'industry': 'Banks - Diversified',
#   'market_cap': 841886859264.0,
#   'pe_ratio': 15.455273,
#   'forward_pe_ratio': 13.38796,
#   'pb_ratio': 2.4352908,
#   'ps_ratio': 5.004231,
#   'ev_to_revenue': 2.283,
#   'ev_to_ebitda': None,
#   'rev_growth': 2.5,
#   'earnings_growth': -3.6999999999999997,
#   'roe': 16.134001,
#   'roa': 1.354,
#   'operating_margin': 41.854,
#   'net_margin': 33.910000000000004,
#   'profit_margin': 33.910000000000004,
#   'beta': 1.066,
#   'one_year_return': np.float64(24.120531926659638),
#   'six_month_return': np.float64(7.173873085163285),
#   'debt_to_equity': None,
#   'total_debt': 1016658001920,
#   'total_cash': 1482637049856,
#   'interest_coverage': np.float64(17.244427363566487),
#   'avg_vol': 9115061},
#  {'ticker': 'V',
#   'sector': 'Financial Services',
#   'company_name': 'Visa Inc.',
#   'industry': 'Credit Services',
#   'market_cap': 632523784192.0,
#   'pe_ratio': 32.132355,
#   'forward_pe_ratio': 22.721159,
#   'pb_ratio': 16.910019,
#   'ps_ratio': 15.813094,
#   'ev_to_revenue': 15.949,
#   'ev_to_ebitda': 22.761,
#   'rev_growth': 11.5,
#   'earnings_growth': -1.4000000000000001,
#   'roe': 52.068000000000005,
#   'roa': 17.261000000000003,
#   'operating_margin': 65.75,
#   'net_margin': 50.144999999999996,
#   'profit_margin': 50.144999999999996,
#   'beta': 0.815,
#   'one_year_return': np.float64(4.04345606753822),
#   'six_month_return': np.float64(-5.750737011265194),
#   'debt_to_equity': 68.807,
#   'total_debt': 26083999744,
#   'total_cash': 18997000192,
#   'interest_coverage': np.float64(42.07640067911715),
#   'avg_vol': 6645787},
#  {'ticker': 'XOM',
#   'sector': 'Energy',
#   'company_name': 'Exxon Mobil Corporation',
#   'industry': 'Oil & Gas Integrated',
#   'market_cap': 550513147904.0,
#   'pe_ratio': 18.796217,
#   'forward_pe_ratio': 18.383982,
#   'pb_ratio': 2.0899558,
#   'ps_ratio': 1.6874225,
#   'ev_to_revenue': 1.793,
#   'ev_to_ebitda': 9.482,
#   'rev_growth': -5.1,
#   'earnings_growth': -8.3,
#   'roe': 11.424,
#   'roa': 5.108,
#   'operating_margin': 11.057,
#   'net_margin': 9.1809995,
#   'profit_margin': 9.1809995,
#   'beta': 0.365,
#   'one_year_return': np.float64(20.256235671223187),
#   'six_month_return': np.float64(21.992733770667904),
#   'debt_to_equity': 15.672,
#   'total_debt': 42035998720,
#   'total_cash': 13813999616,
#   'interest_coverage': np.float64(50.06927710843374),
#   'avg_vol': 15552962},
#  {'ticker': 'ORCL',
#   'sector': 'Technology',
#   'company_name': 'Oracle Corporation',
#   'industry': 'Software - Infrastructure',
#   'market_cap': 545463730176.0,
#   'pe_ratio': 35.68609,
#   'forward_pe_ratio': 23.871164,
#   'pb_ratio': 18.211031,
#   'ps_ratio': 8.939684,
#   'ev_to_revenue': 10.96,
#   'ev_to_ebitda': 25.46,
#   'rev_growth': 14.2,
#   'earnings_growth': 90.9,
#   'roe': 69.026,
#   'roa': 6.864000000000001,
#   'operating_margin': 31.996999999999996,
#   'net_margin': 25.280002000000003,
#   'profit_margin': 25.280002000000003,
#   'beta': 1.651,
#   'one_year_return': np.float64(20.20421367503944),
#   'six_month_return': np.float64(-22.313225803651925),
#   'debt_to_equity': 432.511,
#   'total_debt': 131729997824,
#   'total_cash': 19765999616,
#   'interest_coverage': np.float64(4.957518166573505),
#   'avg_vol': 25310974},
#  {'ticker': 'JNJ',
#   'sector': 'Healthcare',
#   'company_name': 'Johnson & Johnson',
#   'industry': 'Drug Manufacturers - General',
#   'market_cap': 529008951296.0,
#   'pe_ratio': 21.194017,
#   'forward_pe_ratio': 19.090454,
#   'pb_ratio': 6.66434,
#   'ps_ratio': 5.7408,
#   'ev_to_revenue': 6.01,
#   'ev_to_ebitda': 17.348,
#   'rev_growth': 6.800000000000001,
#   'earnings_growth': 91.0,
#   'roe': 33.619,
#   'roa': 8.264000000000001,
#   'operating_margin': 30.200001999999998,
#   'net_margin': 27.259,
#   'profit_margin': 27.259,
#   'beta': 0.333,
#   'one_year_return': np.float64(53.13742102345535),
#   'six_month_return': np.float64(35.97189724761072),
#   'debt_to_equity': 57.766,
#   'total_debt': 45795000320,
#   'total_cash': 18562000896,
#   'interest_coverage': np.float64(23.101986754966887),
#   'avg_vol': 8498991},
#  {'ticker': 'MA',
#   'sector': 'Financial Services',
#   'company_name': 'Mastercard Incorporated',
#   'industry': 'Credit Services',
#   'market_cap': 490562060288.0,
#   'pe_ratio': 34.696293,
#   'forward_pe_ratio': 28.387589,
#   'pb_ratio': 61.798203,
#   'ps_ratio': 15.586264,
#   'ev_to_revenue': 15.867,
#   'ev_to_ebitda': 25.464,
#   'rev_growth': 16.7,
#   'earnings_growth': 22.900000000000002,
#   'roe': 184.86099000000002,
#   'roa': 23.048,
#   'operating_margin': 59.8,
#   'net_margin': 45.275003000000005,
#   'profit_margin': 45.275003000000005,
#   'beta': 0.857,
#   'one_year_return': np.float64(4.328331605045399),
#   'six_month_return': np.float64(-1.533920755586271),
#   'debt_to_equity': 239.715,
#   'total_debt': 18983000064,
#   'total_cash': 10648000512,
#   'interest_coverage': np.float64(24.613003095975234),
#   'avg_vol': 2884058},
#  {'ticker': 'COST',
#   'sector': 'Consumer Defensive',
#   'company_name': 'Costco Wholesale Corporation',
#   'industry': 'Discount Stores',
#   'market_cap': 424756510720.0,
#   'pe_ratio': 51.327793,
#   'forward_pe_ratio': 43.07176,
#   'pb_ratio': 14.01585,
#   'ps_ratio': 1.5148722,
#   'ev_to_revenue': 1.473,
#   'ev_to_ebitda': 31.474,
#   'rev_growth': 8.3,
#   'earnings_growth': 11.4,
#   'roe': 30.325000000000003,
#   'roa': 8.524,
#   'operating_margin': 3.659,
#   'net_margin': 2.9610000000000003,
#   'profit_margin': 2.9610000000000003,
#   'beta': 1.008,
#   'one_year_return': np.float64(4.565638529196159),
#   'six_month_return': np.float64(0.8918357793601173),
#   'debt_to_equity': 26.968,
#   'total_debt': 8172000256,
#   'total_cash': 17183000576,
#   'interest_coverage': np.float64(71.24675324675324),
#   'avg_vol': 2663788},
#  {'ticker': 'PLTR',
#   'sector': 'Technology',
#   'company_name': 'Palantir Technologies Inc.',
#   'industry': 'Software - Infrastructure',
#   'market_cap': 422035095552.0,
#   'pe_ratio': 411.7907,
#   'forward_pe_ratio': 175.06549,
#   'pb_ratio': 64.03978,
#   'ps_ratio': 108.320694,
#   'ev_to_revenue': 107.567,
#   'ev_to_ebitda': 478.536,
#   'rev_growth': 62.8,
#   'earnings_growth': 200.0,
#   'roe': 19.503999999999998,
#   'roa': 7.651,
#   'operating_margin': 33.296,
#   'net_margin': 28.114,
#   'profit_margin': 28.114,
#   'beta': 1.545,
#   'one_year_return': np.float64(155.73369842183698),
#   'six_month_return': np.float64(15.34002240513377),
#   'debt_to_equity': 3.52,
#   'total_debt': 235436000,
#   'total_cash': 6437816832,
#   'interest_coverage': None,
#   'avg_vol': 45673046},
#  {'ticker': 'BAC',
#   'sector': 'Financial Services',
#   'company_name': 'Bank of America Corporation',
#   'industry': 'Banks - Diversified',
#   'market_cap': 384038240256.0,
#   'pe_ratio': 13.80315,
#   'forward_pe_ratio': 10.6642065,
#   'pb_ratio': 1.3857342,
#   'ps_ratio': 3.7856793,
#   'ev_to_revenue': 4.073,
#   'ev_to_ebitda': None,
#   'rev_growth': 12.6,
#   'earnings_growth': 31.5,
#   'roe': 9.871,
#   'roa': 0.881,
#   'operating_margin': 35.292998,
#   'net_margin': 29.224002,
#   'profit_margin': 29.224002,
#   'beta': 1.295,
#   'one_year_return': np.float64(15.368830543261836),
#   'six_month_return': np.float64(12.335866661266959),
#   'debt_to_equity': None,
#   'total_debt': 763981987840,
#   'total_cash': 775117012992,
#   'interest_coverage': None,
#   'avg_vol': 37166050},
#  {'ticker': 'ABBV',
#   'sector': 'Healthcare',
#   'company_name': 'AbbVie Inc.',
#   'industry': 'Drug Manufacturers - General',
#   'market_cap': 383080595456.0,
#   'pe_ratio': 165.45802,
#   'forward_pe_ratio': 15.225517,
#   'pb_ratio': -144.98328,
#   'ps_ratio': 6.4227853,
#   'ev_to_revenue': 7.635,
#   'ev_to_ebitda': 15.427,
#   'rev_growth': 9.1,
#   'earnings_growth': -88.7,
#   'roe': 137.961,
#   'roa': 9.585,
#   'operating_margin': 35.497,
#   'net_margin': 4.004,
#   'profit_margin': 4.004,
#   'beta': 0.35,
#   'one_year_return': np.float64(nan),
#   'six_month_return': np.float64(15.350618121661785),
#   'debt_to_equity': None,
#   'total_debt': 68849000448,
#   'total_cash': 5671000064,
#   'interest_coverage': np.float64(2.3233618233618234),
#   'avg_vol': 5821311}]

# %%
stock_data = json_constructor(url)
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 stock_data = json_constructor(url)
#
# Cell In[6], line 7, in json_constructor(url)
#       5 top_20_market_cap_df = top_20_market_cap(tickers)
#       6 #construct json format
# ----> 7 json_data_output = json_data(top_20_market_cap_df)
#       9 return json_data_output
#
# Cell In[5], line 7, in json_data(df)
#       4 for index, row in df.iterrows():
#       5     ticker = yf.Ticker(row.ticker)
# ----> 7     history = ticker.history(period='1y')
#       9     # Calculate returns - 1 year and 6 months
#      10     if len(history) >= 251:  # 1 year of trading days
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/base.py:129, in TickerBase.history(self, *args, **kwargs)
#     127 @utils.log_indent_decorator
#     128 def history(self, *args, **kwargs) -> pd.DataFrame:
# --> 129     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/scrapers/history.py:207, in PriceHistory.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, rounding, timeout, raise_errors)
#     205         get_fn = self._data.cache_get
#     206 try:
# --> 207     data = get_fn(
#     208         url=url,
#     209         params=params,
#     210         timeout=timeout
#     211     )
#     212     if "Will be right back" in data.text or data is None:
#     213         raise YFDataException("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***")
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:375, in YfData.get(self, url, params, timeout)
#     373 @utils.log_indent_decorator
#     374 def get(self, url, params=None, timeout=30):
# --> 375     response = self._make_request(url, request_method = self._session.get, params=params, timeout=timeout)
#     377     # Accept cookie-consent if redirected to consent page
#     378     if not self._is_this_consent_url(response.url):
#     379         # "Consent Page not detected"
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:444, in YfData._make_request(self, url, request_method, body, params, timeout, data)
#     442 else:
#     443     self._set_cookie_strategy('basic')
# --> 444 crumb, strategy = self._get_cookie_and_crumb(timeout)
#     445 request_args['params']['crumb'] = crumb
#     446 response = request_method(**request_args)
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:358, in YfData._get_cookie_and_crumb(self, timeout)
#     356 with self._cookie_lock:
#     357     if self._cookie_strategy == 'csrf':
# --> 358         crumb = self._get_crumb_csrf()
#     359         if crumb is None:
#     360             # Fail
#     361             self._set_cookie_strategy('basic', have_lock=True)
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/utils.py:95, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      92 logger.debug(f'Entering {func.__name__}()')
#      94 with IndentationContext():
# ---> 95     result = func(*args, **kwargs)
#      97 logger.debug(f'Exiting {func.__name__}()')
#      98 return result
#
# File /opt/homebrew/lib/python3.14/site-packages/yfinance/data.py:341, in YfData._get_crumb_csrf(self, timeout)
#     339 if r.status_code == 429 or "Too Many Requests" in self._crumb:
#     340     utils.get_yf_logger().debug(f"Didn't receive crumb {self._crumb}")
# --> 341     raise YFRateLimitError()
#     343 if self._crumb is None or '<html>' in self._crumb or self._crumb == '':
#     344     utils.get_yf_logger().debug("Didn't receive crumb")
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.

# %%
stock_data
