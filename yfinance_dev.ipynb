# %% [markdown]
# Import Packages

# %%
import pandas as pd
import yfinance as yf
import logging 



pd.set_option('display.float_format', '{:.2f}'.format)

# Configure the 'yfinance' logger to suppress output
logger = logging.getLogger('yfinance')
logger.disabled = True
# Optional: prevent propagation to the root logger as well
logger.propagate = False

# %%
## OUTLINE:
## 1. Value vs. Growth - x=P/E Ratio, y=TTM, r=MarketCap
## 2. Risk-Return - x=beta, y=1yr total return, r=MarketCap
## 3. Profitability vs. Efficiency - x=ROE, y=Net Margin, r=MarketCap
## 4. Quality vs. Valuation - x=P/B Ratio, y=ROA, r=MarketCap
## 5. Leverage vs coverage - x=Debt/EBITDA, y=interest coverage ratio, r=MarketCap
## 6. Momentum vs.Value - 6-Month Price Return (%)

# %% [markdown]
# yfinance API - s&p 500

# %%
def process_tickers(url):
    df = pd.read_csv(url)
    tickers = df['Symbol'].tolist()
    return tickers

# %%
def top_20_market_cap(tickers):
    market_cap_list = []
    ticker_list = []
    for i in tickers:
        ticker = yf.Ticker(i)
        try: 
            market_cap = ticker.info.get('marketCap')
            market_cap_list.append(market_cap)
            ticker_list.append(i)
            if not market_cap or market_cap <= 0:
                shares = ticker.info.get('sharesOutstanding')
                history = ticker.history(period='1d')
                price = history['Close'].iloc[-1]
                market_cap_calc = price * shares
                market_cap_list.append(market_cap_calc)
                ticker_list.append(i)
        except:
            pass
        
    df = pd.DataFrame(data={'ticker': ticker_list, 'marketCap':market_cap_list}).sort_values(by='marketCap', ascending=False).reset_index(drop=True)

    top_20_market_cap = df[df['ticker'] != 'GOOG'][:20].reset_index(drop=True)

    return top_20_market_cap

# %%
def json_data(df):
    json_output = []

    for index, row in df.iterrows():
        ticker = yf.Ticker(row.ticker)

        history = ticker.history(period='1y')

        # Calculate returns
        if len(history) >= 252:  # 1 year of trading days
            one_year_return = ((history['Close'].iloc[-1] / history['Close'].iloc[0]) - 1) * 100
        else:
            one_year_return = None
                
        if len(history) >= 126:  # ~6 months
            six_month_return = ((history['Close'].iloc[-1] / history['Close'].iloc[-126]) - 1) * 100
        else:
            six_month_return = None

        structure =  {
            #core information
            'ticker': row.ticker,
            'sector': ticker.info.get('sector'),
            'company_name': ticker.info.get('longName', ticker),
            'industry': ticker.info.get('industry'),

            #market cap
            'market_cap': row.marketCap,

            # Valuation
            'pe_ratio': ticker.info.get('trailingPE'),
            'forward_pe_ratio':ticker.info.get('forwardPE'),
            'pb_ratio':ticker.info.get('priceToBook'),
            'ps_ratio': ticker.info.get('priceToSalesTrailing12Months'),
            'ev_to_revenue': ticker.info.get('enterpriseToRevenue'),
            'ev_to_ebitda': ticker.info.get('enterpriseToEbitda'),

            #Growth
            'rev_growth': ticker.info.get('revenueGrowth', 0) * 100 if ticker.info.get('revenueGrowth') else None,  # Convert to %
            'earnings_growth': ticker.info.get('earningsGrowth', 0) * 100 if ticker.info.get('earningsGrowth') else None,

            # Profitability
            'roe': ticker.info.get('returnOnEquity', 0) * 100 if ticker.info.get('returnOnEquity') else None,
            'roa': ticker.info.get('returnOnAssets', 0) * 100 if ticker.info.get('returnOnAssets') else None,
            'operating_margin': ticker.info.get('operatingMargins', 0) * 100 if ticker.info.get('operatingMargins') else None,
            'net_margin': ticker. info.get('profitMargins', 0) * 100 if ticker.info.get('profitMargins') else None,
            'profit_margin': ticker.info.get('profitMargins', 0) * 100 if ticker.info.get('profitMargins') else None,
                    
            # Risk
        'beta':ticker.info.get('beta'),
                    
            # Returns (calculated)
            'one_year_return': one_year_return,
            'six_month_return': six_month_return,
                    
            # Leverage
            'debt_to_equity': ticker.info.get('debtToEquity'),
            'total_debt': ticker.info.get('totalDebt'),
            'total_Cash': ticker.info.get('totalCash'),
                    
            # Other
            'avg_vol': ticker.info.get('averageVolume')
        }
        json_output.append(structure)

    return json_output

# %%
def json_constructor(url):
    #scrape s&P 500 ticker list
    tickers = process_tickers(url)
    #baseline df for additional columns
    top_20_market_cap_df = top_20_market_cap(tickers)
    #construct json format
    json_data_output = json_data(top_20_market_cap_df)

    return json_data_output

# %%
# DataSets repo - updated regularly
url = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/main/data/constituents.csv"

# %%
stock_data = json_constructor(url)

# %%
stock_data
# Out:
# [{'ticker': 'NVDA',
#   'sector': 'Technology',
#   'company_name': 'NVIDIA Corporation',
#   'industry': 'Semiconductors',
#   'market_cap': 4502734241792.0,
#   'pe_ratio': 45.664196,
#   'forward_pe_ratio': 24.379698,
#   'pb_ratio': 37.804577,
#   'ps_ratio': 24.060522,
#   'ev_to_revenue': 23.738,
#   'ev_to_ebitda': 39.419,
#   'rev_growth': 62.5,
#   'earnings_growth': 66.7,
#   'roe': 107.35900000000001,
#   'roa': 53.528,
#   'operating_margin': 63.168997000000005,
#   'net_margin': 53.007000000000005,
#   'profit_margin': 53.007000000000005,
#   'beta': 2.314,
#   'one_year_return': None,
#   'six_month_return': np.float64(8.354269958512361),
#   'debt_to_equity': 9.102,
#   'total_debt': 10821999616,
#   'total_Cash': 60608000000,
#   'avg_vol': 184816293},
#  {'ticker': 'GOOGL',
#   'sector': 'Communication Services',
#   'company_name': 'Alphabet Inc.',
#   'industry': 'Internet Content & Information',
#   'market_cap': 4019528663040.0,
#   'pe_ratio': 32.79249,
#   'forward_pe_ratio': 29.467678,
#   'pb_ratio': 10.359941,
#   'ps_ratio': 10.427442,
#   'ev_to_revenue': 10.145,
#   'ev_to_ebitda': 26.937,
#   'rev_growth': 15.9,
#   'earnings_growth': 35.3,
#   'roe': 35.449999999999996,
#   'roa': 16.275999,
#   'operating_margin': 30.512,
#   'net_margin': 32.233003,
#   'profit_margin': 32.233003,
#   'beta': 1.086,
#   'one_year_return': None,
#   'six_month_return': np.float64(82.62310917765099),
#   'debt_to_equity': 11.424,
#   'total_debt': 44195000320,
#   'total_Cash': 98496004096,
#   'avg_vol': 35932538},
#  {'ticker': 'AAPL',
#   'sector': 'Technology',
#   'company_name': 'Apple Inc.',
#   'industry': 'Consumer Electronics',
#   'market_cap': 3845545787392.0,
#   'pe_ratio': 34.83936,
#   'forward_pe_ratio': 28.438677,
#   'pb_ratio': 52.143856,
#   'ps_ratio': 9.240524,
#   'ev_to_revenue': 9.348,
#   'ev_to_ebitda': 26.876,
#   'rev_growth': 7.9,
#   'earnings_growth': 91.2,
#   'roe': 171.42199,
#   'roa': 22.964000000000002,
#   'operating_margin': 31.647,
#   'net_margin': 26.915001999999998,
#   'profit_margin': 26.915001999999998,
#   'beta': 1.093,
#   'one_year_return': None,
#   'six_month_return': np.float64(24.718054796185363),
#   'debt_to_equity': 152.411,
#   'total_debt': 112377004032,
#   'total_Cash': 54697000960,
#   'avg_vol': 45481135},
#  {'ticker': 'MSFT',
#   'sector': 'Technology',
#   'company_name': 'Microsoft Corporation',
#   'industry': 'Software - Infrastructure',
#   'market_cap': 3546958266368.0,
#   'pe_ratio': 33.98718,
#   'forward_pe_ratio': 25.452803,
#   'pb_ratio': 9.77027,
#   'ps_ratio': 12.072203,
#   'ev_to_revenue': 12.187,
#   'ev_to_ebitda': 21.513,
#   'rev_growth': 18.4,
#   'earnings_growth': 12.7,
#   'roe': 32.241002,
#   'roa': 14.655999999999999,
#   'operating_margin': 48.873,
#   'net_margin': 35.707,
#   'profit_margin': 35.707,
#   'beta': 1.073,
#   'one_year_return': None,
#   'six_month_return': np.float64(-5.330154631154582),
#   'debt_to_equity': 33.154,
#   'total_debt': 120375001088,
#   'total_Cash': 102012002304,
#   'avg_vol': 23060395},
#  {'ticker': 'AMZN',
#   'sector': 'Consumer Cyclical',
#   'company_name': 'Amazon.com, Inc.',
#   'industry': 'Internet Retail',
#   'market_cap': 2634817470464.0,
#   'pe_ratio': 34.81215,
#   'forward_pe_ratio': 31.347298,
#   'pb_ratio': 7.1260877,
#   'ps_ratio': 3.8112297,
#   'ev_to_revenue': 3.921,
#   'ev_to_ebitda': 19.405,
#   'rev_growth': 13.4,
#   'earnings_growth': 36.4,
#   'roe': 24.326999999999998,
#   'roa': 7.495,
#   'operating_margin': 11.057,
#   'net_margin': 11.063,
#   'profit_margin': 11.063,
#   'beta': 1.376,
#   'one_year_return': None,
#   'six_month_return': np.float64(8.888886492004833),
#   'debt_to_equity': 43.405,
#   'total_debt': 160437993472,
#   'total_Cash': 94196998144,
#   'avg_vol': 44986493},
#  {'ticker': 'AVGO',
#   'sector': 'Technology',
#   'company_name': 'Broadcom Inc.',
#   'industry': 'Semiconductors',
#   'market_cap': 1669923995648.0,
#   'pe_ratio': 73.99369,
#   'forward_pe_ratio': 25.008236,
#   'pb_ratio': 5.9473834,
#   'ps_ratio': 26.138714,
#   'ev_to_revenue': 2.679,
#   'ev_to_ebitda': 4.89,
#   'rev_growth': 16.400000000000002,
#   'earnings_growth': 188.1,
#   'roe': 31.048,
#   'roa': 9.788,
#   'operating_margin': 31.765,
#   'net_margin': 36.198002,
#   'profit_margin': 36.198002,
#   'beta': 1.218,
#   'one_year_return': None,
#   'six_month_return': np.float64(25.823498276650582),
#   'debt_to_equity': 166.032,
#   'total_debt': 40456998912,
#   'total_Cash': 11105000448,
#   'avg_vol': 28806979},
#  {'ticker': 'META',
#   'sector': 'Communication Services',
#   'company_name': 'Meta Platforms, Inc.',
#   'industry': 'Internet Content & Information',
#   'market_cap': 1618102976512.0,
#   'pe_ratio': 28.40575,
#   'forward_pe_ratio': 21.113523,
#   'pb_ratio': 8.339438,
#   'ps_ratio': 8.540694,
#   'ev_to_revenue': 8.723,
#   'ev_to_ebitda': 16.796,
#   'rev_growth': 26.200000000000003,
#   'earnings_growth': -82.6,
#   'roe': 32.643001999999996,
#   'roa': 18.013,
#   'operating_margin': 40.075,
#   'net_margin': 30.891999999999996,
#   'profit_margin': 30.891999999999996,
#   'beta': 1.287,
#   'one_year_return': None,
#   'six_month_return': np.float64(-9.496595249129602),
#   'debt_to_equity': 26.311,
#   'total_debt': 51059998720,
#   'total_Cash': 44447997952,
#   'avg_vol': 17976953},
#  {'ticker': 'TSLA',
#   'sector': 'Consumer Cyclical',
#   'company_name': 'Tesla, Inc.',
#   'industry': 'Auto Manufacturers',
#   'market_cap': 1493159772160.0,
#   'pe_ratio': 305.41495,
#   'forward_pe_ratio': 205.64027,
#   'pb_ratio': 18.661568,
#   'ps_ratio': 15.613437,
#   'ev_to_revenue': 15.193,
#   'ev_to_ebitda': 134.928,
#   'rev_growth': 11.600000000000001,
#   'earnings_growth': -37.1,
#   'roe': 6.7909999999999995,
#   'roa': 2.35,
#   'operating_margin': 6.628,
#   'net_margin': 5.314,
#   'profit_margin': 5.314,
#   'beta': 1.835,
#   'one_year_return': None,
#   'six_month_return': np.float64(44.4623184305728),
#   'debt_to_equity': 17.082,
#   'total_debt': 13788000256,
#   'total_Cash': 41647001600,
#   'avg_vol': 79266427},
#  {'ticker': 'LLY',
#   'sector': 'Healthcare',
#   'company_name': 'Eli Lilly and Company',
#   'industry': 'Drug Manufacturers - General',
#   'market_cap': 969069756416.0,
#   'pe_ratio': 52.938297,
#   'forward_pe_ratio': 32.87521,
#   'pb_ratio': 40.700302,
#   'ps_ratio': 16.30887,
#   'ev_to_revenue': 16.577,
#   'ev_to_ebitda': 34.287,
#   'rev_growth': 53.900000000000006,
#   'earnings_growth': 480.40000000000003,
#   'roe': 96.47,
#   'roa': 17.603001,
#   'operating_margin': 48.294,
#   'net_margin': 30.986000000000004,
#   'profit_margin': 30.986000000000004,
#   'beta': 0.347,
#   'one_year_return': None,
#   'six_month_return': np.float64(40.58508165372678),
#   'debt_to_equity': 178.516,
#   'total_debt': 42577600512,
#   'total_Cash': 9913499648,
#   'avg_vol': 3494748},
#  {'ticker': 'WMT',
#   'sector': 'Consumer Defensive',
#   'company_name': 'Walmart Inc.',
#   'industry': 'Discount Stores',
#   'market_cap': 940557271040.0,
#   'pe_ratio': 41.248253,
#   'forward_pe_ratio': 39.5919,
#   'pb_ratio': 9.786793,
#   'ps_ratio': 1.3378032,
#   'ev_to_revenue': 1.39,
#   'ev_to_ebitda': 22.876,
#   'rev_growth': 5.800000000000001,
#   'earnings_growth': 35.199999999999996,
#   'roe': 23.660999999999998,
#   'roa': 6.539000000000001,
#   'operating_margin': 3.73,
#   'net_margin': 3.259,
#   'profit_margin': 3.259,
#   'beta': 0.661,
#   'one_year_return': None,
#   'six_month_return': np.float64(24.21278540103955),
#   'debt_to_equity': 66.747,
#   'total_debt': 68423999488,
#   'total_Cash': 10581999616,
#   'avg_vol': 19069664},
#  {'ticker': 'JPM',
#   'sector': 'Financial Services',
#   'company_name': 'JPMorgan Chase & Co.',
#   'industry': 'Banks - Diversified',
#   'market_cap': 892267593728.0,
#   'pe_ratio': 16.07978,
#   'forward_pe_ratio': 15.436226,
#   'pb_ratio': 2.5968132,
#   'ps_ratio': 5.335603,
#   'ev_to_revenue': 3.906,
#   'ev_to_ebitda': None,
#   'rev_growth': 8.799999999999999,
#   'earnings_growth': 16.0,
#   'roe': 16.436999999999998,
#   'roa': 1.323,
#   'operating_margin': 43.708000000000006,
#   'net_margin': 34.699999999999996,
#   'profit_margin': 34.699999999999996,
#   'beta': 1.066,
#   'one_year_return': None,
#   'six_month_return': np.float64(14.304093802369543),
#   'debt_to_equity': None,
#   'total_debt': 1148076032000,
#   'total_Cash': 1411027042304,
#   'avg_vol': 8795769},
#  {'ticker': 'V',
#   'sector': 'Financial Services',
#   'company_name': 'Visa Inc.',
#   'industry': 'Credit Services',
#   'market_cap': 662340763648.0,
#   'pe_ratio': 33.614105,
#   'forward_pe_ratio': 23.798693,
#   'pb_ratio': 17.707151,
#   'ps_ratio': 16.55852,
#   'ev_to_revenue': 16.935,
#   'ev_to_ebitda': 24.168,
#   'rev_growth': 11.5,
#   'earnings_growth': -1.4000000000000001,
#   'roe': 52.068000000000005,
#   'roa': 17.261000000000003,
#   'operating_margin': 65.75,
#   'net_margin': 50.144999999999996,
#   'profit_margin': 50.144999999999996,
#   'beta': 0.815,
#   'one_year_return': None,
#   'six_month_return': np.float64(-0.7305315031559512),
#   'debt_to_equity': 68.807,
#   'total_debt': 26083999744,
#   'total_Cash': 18997000192,
#   'avg_vol': 6169808},
#  {'ticker': 'ORCL',
#   'sector': 'Technology',
#   'company_name': 'Oracle Corporation',
#   'industry': 'Software - Infrastructure',
#   'market_cap': 588072222720.0,
#   'pe_ratio': 38.473682,
#   'forward_pe_ratio': 25.735842,
#   'pb_ratio': 19.633572,
#   'ps_ratio': 9.6380005,
#   'ev_to_revenue': 11.191,
#   'ev_to_ebitda': 25.997,
#   'rev_growth': 14.2,
#   'earnings_growth': 90.9,
#   'roe': 69.026,
#   'roa': 6.864000000000001,
#   'operating_margin': 31.996999999999996,
#   'net_margin': 25.280002000000003,
#   'profit_margin': 25.280002000000003,
#   'beta': 1.651,
#   'one_year_return': None,
#   'six_month_return': np.float64(-12.505464369311659),
#   'debt_to_equity': 432.511,
#   'total_debt': 131729997824,
#   'total_Cash': 19765999616,
#   'avg_vol': 25133141},
#  {'ticker': 'XOM',
#   'sector': 'Energy',
#   'company_name': 'Exxon Mobil Corporation',
#   'industry': 'Oil & Gas Integrated',
#   'market_cap': 528770531328.0,
#   'pe_ratio': 18.027617,
#   'forward_pe_ratio': 17.714346,
#   'pb_ratio': 2.0074127,
#   'ps_ratio': 1.6207775,
#   'ev_to_revenue': 1.721,
#   'ev_to_ebitda': 9.1,
#   'rev_growth': -5.1,
#   'earnings_growth': -8.3,
#   'roe': 11.424,
#   'roa': 5.108,
#   'operating_margin': 11.057,
#   'net_margin': 9.1809995,
#   'profit_margin': 9.1809995,
#   'beta': 0.365,
#   'one_year_return': None,
#   'six_month_return': np.float64(11.840469551020316),
#   'debt_to_equity': 15.672,
#   'total_debt': 42035998720,
#   'total_Cash': 13813999616,
#   'avg_vol': 15055041},
#  {'ticker': 'MA',
#   'sector': 'Financial Services',
#   'company_name': 'Mastercard Incorporated',
#   'industry': 'Credit Services',
#   'market_cap': 511923847168.0,
#   'pe_ratio': 36.18403,
#   'forward_pe_ratio': 29.625477,
#   'pb_ratio': 64.48924,
#   'ps_ratio': 16.264977,
#   'ev_to_revenue': 16.686,
#   'ev_to_ebitda': 26.779,
#   'rev_growth': 16.7,
#   'earnings_growth': 22.900000000000002,
#   'roe': 184.86099000000002,
#   'roa': 23.048,
#   'operating_margin': 59.8,
#   'net_margin': 45.275003000000005,
#   'profit_margin': 45.275003000000005,
#   'beta': 0.857,
#   'one_year_return': None,
#   'six_month_return': np.float64(3.1832568313254983),
#   'debt_to_equity': 239.715,
#   'total_debt': 18983000064,
#   'total_Cash': 10648000512,
#   'avg_vol': 2750743},
#  {'ticker': 'JNJ',
#   'sector': 'Healthcare',
#   'company_name': 'Johnson & Johnson',
#   'industry': 'Drug Manufacturers - General',
#   'market_cap': 505277382656.0,
#   'pe_ratio': 20.282398,
#   'forward_pe_ratio': 18.218208,
#   'pb_ratio': 6.365375,
#   'ps_ratio': 5.483265,
#   'ev_to_revenue': 5.639,
#   'ev_to_ebitda': 16.279,
#   'rev_growth': 6.800000000000001,
#   'earnings_growth': 91.0,
#   'roe': 33.619,
#   'roa': 8.264000000000001,
#   'operating_margin': 30.200001999999998,
#   'net_margin': 27.259,
#   'profit_margin': 27.259,
#   'beta': 0.333,
#   'one_year_return': None,
#   'six_month_return': np.float64(37.011472940547854),
#   'debt_to_equity': 57.766,
#   'total_debt': 45795000320,
#   'total_Cash': 18562000896,
#   'avg_vol': 8435006},
#  {'ticker': 'PLTR',
#   'sector': 'Technology',
#   'company_name': 'Palantir Technologies Inc.',
#   'industry': 'Software - Infrastructure',
#   'market_cap': 427612307456.0,
#   'pe_ratio': 417.23257,
#   'forward_pe_ratio': 177.379,
#   'pb_ratio': 64.88608,
#   'ps_ratio': 109.75216,
#   'ev_to_revenue': 107.011,
#   'ev_to_ebitda': 476.06,
#   'rev_growth': 62.8,
#   'earnings_growth': 200.0,
#   'roe': 19.503999999999998,
#   'roa': 7.651,
#   'operating_margin': 33.296,
#   'net_margin': 28.114,
#   'profit_margin': 28.114,
#   'beta': 1.545,
#   'one_year_return': None,
#   'six_month_return': np.float64(20.749765413322873),
#   'debt_to_equity': 3.52,
#   'total_debt': 235436000,
#   'total_Cash': 6437816832,
#   'avg_vol': 46182659},
#  {'ticker': 'COST',
#   'sector': 'Consumer Defensive',
#   'company_name': 'Costco Wholesale Corporation',
#   'industry': 'Discount Stores',
#   'market_cap': 418687647744.0,
#   'pe_ratio': 50.48608,
#   'forward_pe_ratio': 42.456352,
#   'pb_ratio': 13.815593,
#   'ps_ratio': 1.4932278,
#   'ev_to_revenue': 1.432,
#   'ev_to_ebitda': 30.592,
#   'rev_growth': 8.3,
#   'earnings_growth': 11.4,
#   'roe': 30.325000000000003,
#   'roa': 8.524,
#   'operating_margin': 3.659,
#   'net_margin': 2.9610000000000003,
#   'profit_margin': 2.9610000000000003,
#   'beta': 1.008,
#   'one_year_return': None,
#   'six_month_return': np.float64(-2.269077722640267),
#   'debt_to_equity': 26.968,
#   'total_debt': 8172000256,
#   'total_Cash': 17183000576,
#   'avg_vol': 2627369},
#  {'ticker': 'BAC',
#   'sector': 'Financial Services',
#   'company_name': 'Bank of America Corporation',
#   'industry': 'Banks - Diversified',
#   'market_cap': 417241890816.0,
#   'pe_ratio': 15.079234,
#   'forward_pe_ratio': 12.65724,
#   'pb_ratio': 1.4542435,
#   'ps_ratio': 4.112986,
#   'ev_to_revenue': 4.167,
#   'ev_to_ebitda': None,
#   'rev_growth': 12.6,
#   'earnings_growth': 31.5,
#   'roe': 9.871,
#   'roa': 0.881,
#   'operating_margin': 35.292998,
#   'net_margin': 29.224002,
#   'profit_margin': 29.224002,
#   'beta': 1.295,
#   'one_year_return': None,
#   'six_month_return': np.float64(20.878393440026045),
#   'debt_to_equity': None,
#   'total_debt': 763981987840,
#   'total_Cash': 775117012992,
#   'avg_vol': 36727090},
#  {'ticker': 'MU',
#   'sector': 'Technology',
#   'company_name': 'Micron Technology, Inc.',
#   'industry': 'Semiconductors',
#   'market_cap': 389279875072.0,
#   'pe_ratio': 32.846153,
#   'forward_pe_ratio': 8.620691,
#   'pb_ratio': 6.6225634,
#   'ps_ratio': 9.200224,
#   'ev_to_revenue': 9.231,
#   'ev_to_ebitda': 17.567,
#   'rev_growth': 56.699999999999996,
#   'earnings_growth': 175.4,
#   'roe': 22.554001,
#   'roa': 10.934000000000001,
#   'operating_margin': 44.974998,
#   'net_margin': 28.145999999999997,
#   'profit_margin': 28.145999999999997,
#   'beta': 1.503,
#   'one_year_return': None,
#   'six_month_return': np.float64(188.25776449094835),
#   'debt_to_equity': 21.244,
#   'total_debt': 12492999680,
#   'total_Cash': 10318000128,
#   'avg_vol': 26769804}]
